# %% [markdown]
# # Loss Function

# %%
# Loss Function -- > y_actual - y_predicted

# Numerical data scenerio ---- > MSE , MAE

# Categorical data scenerio --- >

# (1). When we have 2 sub-categories in target column - Binarycros
# (2). When we have more than 2 sub-categories in target column -
# / Sparsecategorical cross entropy

# %%
# Optimizers ---- > Reduce or minize the distance from predicted point to actual point.

# %%
# We know that Equation of simple line is :
# y_act = mx + b .... (1)
# y_pred = mx + b

# here (x,y) --- > co-ordinates , m = slope , b = intercept

# Now we will calculate Loss w.r.t. MSE
# L = 1/n * (y_act - y_pred) ** 2
# n = n(featurs) === > let suppose if we have 1 column --- > n(features) = 1

# L = (y_act - y_pred) ** 2
# L = (y -(mx+b) ) ** 2
# L = (y - mx - b) ** 2 ... (2)

# %%
# Equ. (2) differentiation calcuate w.r.t. intercept(b) ::::
# dL/db = 2(y-mx-b) [dy/db - dmx/db - db/db]

# dL/db = 2(y-mx-b) [0 - 0 - 1]

# dL/db = -2(y-mx-b) .......... (3)

# Equ. (2) differentiation calculate w.r.t. slope(m) ::::
# dL/dm = 2(y-mx-b) [dy/dmdm - dmx/dm - db/dml] 
# dL/dm = 2(y-mx-b)[0 - x - 0]
# dl/dm = -2(y-mx-b)(x) ...... (4)

now
In general lr = 0.001


# b_new = b_old - learning_rate * dL/db ..... (5)

# m_new = m_old - learning_rate * dL/dm .... (6)

# So , our finally New Line Equation will be ::::

# y = m_new*X + b_new ...... (7)
